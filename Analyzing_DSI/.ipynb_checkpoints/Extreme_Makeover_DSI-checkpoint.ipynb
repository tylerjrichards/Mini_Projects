# %% [markdown]
# # Extreme Makeover: DSI Edition

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/ee/c4/bf82dc7ee81ac798cd64d8ec0884c07d59f82f45f4faf878a860c1c1d487/matplotlib-2.2.3-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (13.8MB)
#     100% |████████████████████████████████| 13.8MB 2.4MB/s ta 0:00:011
# Requirement already satisfied: six>=1.10 in /usr/local/Cellar/ipython/6.5.0/libexec/vendor/lib/python3.7/site-packages (from matplotlib) (1.11.0)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/site-packages (from matplotlib) (2018.5)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/Cellar/ipython/6.5.0/libexec/vendor/lib/python3.7/site-packages (from matplotlib) (2.7.3)
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/68/f2/21ec13269a420c063a3d7d8c87dac030da7b00fc6b27fa88cfb1c72a645b/kiwisolver-1.0.1-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (107kB)
#     100% |████████████████████████████████| 112kB 8.2MB/s ta 0:00:01
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/6a/8a/718fd7d3458f9fab8e67186b00abdd345b639976bc7fb3ae722e1b026a50/pyparsing-2.2.0-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 5.0MB/s ta 0:00:011
# Requirement already satisfied: numpy>=1.7.1 in /usr/local/lib/python3.7/site-packages (from matplotlib) (1.15.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (40.0.0)
# Installing collected packages: cycler, kiwisolver, pyparsing, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.0.1 matplotlib-2.2.3 pyparsing-2.2.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
workshop_data = pd.read_csv("workshops.csv")

# %%
workshop_data['Programming_Lang']

# %%
# Out:
#       Unnamed: 0                              Workshop_Type  \
# 0              0               Python 2 Sign in (Responses)
# 1              1               Python 2 Sign in (Responses)
# 2              2               Python 2 Sign in (Responses)
# 3              3               Python 2 Sign in (Responses)
# 4              4               Python 2 Sign in (Responses)
# 5              5               Python 2 Sign in (Responses)
# 6              6               Python 2 Sign in (Responses)
# 7              7               Python 2 Sign in (Responses)
# 8              8               Python 2 Sign in (Responses)
# 9              9               Python 2 Sign in (Responses)
# 10            10               Python 2 Sign in (Responses)
# 11            11               Python 2 Sign in (Responses)
# 12            12               Python 2 Sign in (Responses)
# 13            13               Python 2 Sign in (Responses)
# 14            14               Python 2 Sign in (Responses)
# 15            15               Python 2 Sign in (Responses)
# 16            16               Python 2 Sign in (Responses)
# 17            17               Python 2 Sign in (Responses)
# 18            18               Python 2 Sign in (Responses)
# 19            19               Python 2 Sign in (Responses)
# 20            20               Python 2 Sign in (Responses)
# 21            21               Python 2 Sign in (Responses)
# 22            22               Python 2 Sign in (Responses)
# 23            23               Python 2 Sign in (Responses)
# 24            24               Python 2 Sign in (Responses)
# 25            25               Python 2 Sign in (Responses)
# 26            26               Python 2 Sign in (Responses)
# 27            27               Python 2 Sign in (Responses)
# 28            28               Python 2 Sign in (Responses)
# 29            29               Python 2 Sign in (Responses)
# ...          ...                                        ...
# 2058        2058  Python 0 #2 Sign-in Fall 2016 (Responses)
# 2059        2059  Python 0 #2 Sign-in Fall 2016 (Responses)
# 2060        2060  Python 0 #2 Sign-in Fall 2016 (Responses)
# 2061        2061  Python 0 #2 Sign-in Fall 2016 (Responses)
# 2062        2062  Python 0 #2 Sign-in Fall 2016 (Responses)
# 2063        2063  Python 0 #2 Sign-in Fall 2016 (Responses)
# 2064        2064  Python 0 #2 Sign-in Fall 2016 (Responses)
# 2065        2065     Spring 2017 GBM #1 Sign In (Responses)
# 2066        2066     Spring 2017 GBM #1 Sign In (Responses)
# 2067        2067     Spring 2017 GBM #1 Sign In (Responses)
# 2068        2068     Spring 2017 GBM #1 Sign In (Responses)
# 2069        2069     Spring 2017 GBM #1 Sign In (Responses)
# 2070        2070     Spring 2017 GBM #1 Sign In (Responses)
# 2071        2071     Spring 2017 GBM #1 Sign In (Responses)
# 2072        2072     Spring 2017 GBM #1 Sign In (Responses)
# 2073        2073     Spring 2017 GBM #1 Sign In (Responses)
# 2074        2074     Spring 2017 GBM #1 Sign In (Responses)
# 2075        2075     Spring 2017 GBM #1 Sign In (Responses)
# 2076        2076     Spring 2017 GBM #1 Sign In (Responses)
# 2077        2077     Spring 2017 GBM #1 Sign In (Responses)
# 2078        2078     Spring 2017 GBM #1 Sign In (Responses)
# 2079        2079     Spring 2017 GBM #1 Sign In (Responses)
# 2080        2080     Spring 2017 GBM #1 Sign In (Responses)
# 2081        2081     Spring 2017 GBM #1 Sign In (Responses)
# 2082        2082     Spring 2017 GBM #1 Sign In (Responses)
# 2083        2083     Spring 2017 GBM #1 Sign In (Responses)
# 2084        2084     Spring 2017 GBM #1 Sign In (Responses)
# 2085        2085     Spring 2017 GBM #1 Sign In (Responses)
# 2086        2086     Spring 2017 GBM #1 Sign In (Responses)
# 2087        2087     Spring 2017 GBM #1 Sign In (Responses)
#
#                 Timestamp                         email gender  \
# 0     2015-03-31 16:48:00                jcagle@ufl.edu    NaN
# 1     2015-03-31 16:49:00             anand9955@ufl.edu    NaN
# 2     2015-03-31 16:49:00               srbshrm@ufl.edu    NaN
# 3     2015-03-31 16:56:00              goleary5@ufl.edu    NaN
# 4     2015-03-31 17:00:00           taliajbrown@ufl.edu    NaN
# 5     2015-03-31 17:00:00             rmichelen@ufl.edu    NaN
# 6     2015-03-31 17:01:00          demaio@astro.ufl.edu    NaN
# 7     2015-03-31 17:01:00  rawagnerkaiser@astro.ufl.edu    NaN
# 8     2015-03-31 17:02:00            alexwebber@ufl.edu    NaN
# 9     2015-03-31 17:02:00           pranav91690@ufl.edu    NaN
# 10    2015-03-31 17:02:00             cshilpa12@ufl.edu    NaN
# 11    2015-03-31 17:03:00              dytu0316@ufl.edu    NaN
# 12    2015-03-31 17:04:00             yaggarwal@ufl.edu    NaN
# 13    2015-03-31 17:04:00           rohitchawla@ufl.edu    NaN
# 14    2015-03-31 17:05:00           twickes32@gmail.com    NaN
# 15    2015-03-31 17:05:00          user.punam@gmail.com    NaN
# 16    2015-03-31 17:05:00          swagshaggy@gmail.com    NaN
# 17    2015-03-31 17:06:00              keerti14@ufl.edu    NaN
# 18    2015-03-31 17:06:00           ravleenkaur@ufl.edu    NaN
# 19    2015-03-31 17:07:00        alexbujduveanu@ufl.edu    NaN
# 20    2015-03-31 17:07:00             brucha220@ufl.edu    NaN
# 21    2015-03-31 17:08:00            cottog8444@ufl.edu    NaN
# 22    2015-03-31 17:08:00          sudeepgaddam@ufl.edu    NaN
# 23    2015-03-31 17:09:00              smaddula@ufl.edu    NaN
# 24    2015-03-31 17:09:00            chandram10@ufl.edu    NaN
# 25    2015-03-31 17:10:00                   ya1@ufl.edu    NaN
# 12              Yogesh       Aggarwal                                 NaN
# 13              Rohit          Chawla                                 NaN
# 14             Takashi         Wickes                                 NaN
# 15               Punam         Mahato                                 NaN
# 16              Shagun          Arora                                 NaN
# 17              Keerti       Randhawa                                 NaN
# 18             Ravleen           Kaur                                 NaN
# 19                Alex     Bujduveanu                                 NaN
# 20              Austin          Bruch                                 NaN
# 21             Garrett         Cotton                                 NaN
# 22        Sudeep Reddy         Gaddam                                 NaN
# 23           Siddardha        Maddula                                 NaN
# 24             Matthew        Chandra                                 NaN
# 25                  Ya          Zhang                                 NaN
# 26                 Hao          Zhang                                 NaN
# 27                Nick          Evans                                 NaN
# 28            Karishma          Gupta                                 NaN
# 29              Yogita      Deshpande                                 NaN
# ...                ...            ...                                 ...
# 2058           Patrick         O'Hern                                 NaN
# 2059          Kaivalya           Kari                                 NaN
# 2060            Sidney           Tsai                                 NaN
# 2061           Charlie       Qualmann                                 NaN
# 2062             Yufan            Lin                                 NaN
# 2063               NaN            NaN                                 NaN
# 2064            Jenny         Solomon                                 NaN
# 2065            Steven      Remington                    Computer Science
# 2066            Yining            Yan                                 ISE
# 2067           Hongtao           Wang                                 ISE
# 2068             Kanis       Bootsita   Materials Science and Engineering
# 2069         Alexander          Todor              industrial engineering
# 2070             Sofia           Vega                          Statistics
# 2071             Kejti           Lita                    Computer Science
# 2072              Ross        Spencer                    Computer Science
# 2073              Nick           Lang                                  cs
# 2074             Katie       Kempfert          Statistics and Mathematics
# 2075            Joseph          Braun                          Statistics
# 2076            Hannah          Allen                Nutritional Sciences
# 2077            Zitong           Zhao  industrial and systems engineering
# 2078           Meghana       Tatineni                          Statistics
# 2079           Allison           Kahn                    Computer Science
# 2080           Patrick         Barber                    Computer Science
# 2081         Charlotte         Talham                          Statistics
# 2082           Charlie       Qualmann     COmputer SCience and Statistics
# 2083           Michael     Strohmeier                    Computer Science
# 2084  Venkat Narayanan     Veerasekar  Industrial and Systems Engineering
# 2085            Joshua       Villegas                          Statistics
# 2086          Dianteng           Chen       Physics/Computational physics
# 2087           Ricardo  Brown-Salazar           Interdisciplinary Ecology
#
#      academic standing                                 study       ...        \
# 0                  NaN                                   NaN       ...
# 1                  NaN                                   NaN       ...
# 2                  NaN                                   NaN       ...
# 3                  NaN                                   NaN       ...
# 4                  NaN                                   NaN       ...
# 5                  NaN                                   NaN       ...
# 6                  NaN                                   NaN       ...
# 7                  NaN                                   NaN       ...
# 8                  NaN                                   NaN       ...
# 9                  NaN                                   NaN       ...
# 10                 NaN                                   NaN       ...
# 11                 NaN                                   NaN       ...
# 12                 NaN                                   NaN       ...
# 13                 NaN                                   NaN       ...
# 14                 NaN                                   NaN       ...
# 15                 NaN                                   NaN       ...
# 16                 NaN                                   NaN       ...
# 17                 NaN                                   NaN       ...
# 18                 NaN                                   NaN       ...
# 19                 NaN                                   NaN       ...
# 20                 NaN                                   NaN       ...
# 21                 NaN                                   NaN       ...
# 22                 NaN                                   NaN       ...
# 23                 NaN                                   NaN       ...
# 24                 NaN                                   NaN       ...
# 25                 NaN                                   NaN       ...
# 26                 NaN                                   NaN       ...
# 27                 NaN                                   NaN       ...
# 28                 NaN                                   NaN       ...
# 29                 NaN                                   NaN       ...
# ...                ...                                   ...       ...
# 2058               NaN                                   NaN       ...
# 2059               NaN                                   NaN       ...
# 2060               NaN                                   NaN       ...
# 2061               NaN                                   NaN       ...
# 2062               NaN                                   NaN       ...
# 2063               NaN                                   NaN       ...
# 2064               NaN                                   NaN       ...
# 2065            1 to 2                     ['comput', 'sci']       ...
# 2066          Graduate                                ['is']       ...
# 2067          Graduate                                ['is']       ...
# 2068            1 to 2        ['mat', 'sci', 'and', 'engin']       ...
# 2069            1 to 2                   ['indust', 'engin']       ...
# 2070            1 to 2                              ['stat']       ...
# 2071            1 to 2                     ['comput', 'sci']       ...
# 2072            1 to 2                     ['comput', 'sci']       ...
# 2073            1 to 2                                ['cs']       ...
# 2074            1 to 2             ['stat', 'and', 'mathem']       ...
# 2075            1 to 2                              ['stat']       ...
# 2076          Graduate                     ['nutrit', 'sci']       ...
# 2077          Graduate  ['indust', 'and', 'system', 'engin']       ...
# 2078            1 to 2                              ['stat']       ...
# 2079            1 to 2                     ['comput', 'sci']       ...
# 2080            1 to 2                     ['comput', 'sci']       ...
# 2081            1 to 2                              ['stat']       ...
# 2082            1 to 2      ['comput', 'sci', 'and', 'stat']       ...
# 2083            1 to 2                     ['comput', 'sci']       ...
# 2084          Graduate  ['indust', 'and', 'system', 'engin']       ...
# 2085            1 to 2                              ['stat']       ...
# 2086          Graduate            ['phys', 'comput', 'phys']       ...
# 2087          Graduate          ['interdisciplin', 'ecolog']       ...
#
#      first attendance python_attendance race ethnicity feedback no_punc  \
# 0                 NaN               NaN  NaN       NaN      NaN     NaN
# 1                 NaN               NaN  NaN       NaN      NaN     NaN
# 2                 NaN               NaN  NaN       NaN      NaN     NaN
# 3                 NaN               NaN  NaN       NaN      NaN     NaN
# 4                 NaN               NaN  NaN       NaN      NaN     NaN
# 5                 NaN               NaN  NaN       NaN      NaN     NaN
# 6                 NaN               NaN  NaN       NaN      NaN     NaN
# 7                 NaN               NaN  NaN       NaN      NaN     NaN
# 8                 NaN               NaN  NaN       NaN      NaN     NaN
# 9                 NaN               NaN  NaN       NaN      NaN     NaN
# 10                NaN               NaN  NaN       NaN      NaN     NaN
# 11                NaN               NaN  NaN       NaN      NaN     NaN
# 12                NaN               NaN  NaN       NaN      NaN     NaN
# 13                NaN               NaN  NaN       NaN      NaN     NaN
# 14                NaN               NaN  NaN       NaN      NaN     NaN
# 15                NaN               NaN  NaN       NaN      NaN     NaN
# 16                NaN               NaN  NaN       NaN      NaN     NaN
# 17                NaN               NaN  NaN       NaN      NaN     NaN
# 18                NaN               NaN  NaN       NaN      NaN     NaN
# 12        NaN      NaN                    Facebook group posting
# 13        NaN      NaN                    Facebook group posting
# 14        NaN      NaN                        Friend or collegue
# 15        NaN      NaN                           Email list serv
# 16        NaN      NaN                    Facebook group posting
# 17        NaN      NaN                    Facebook group posting
# 18        NaN      NaN                    Facebook group posting
# 19        NaN      NaN                    Facebook group posting
# 20        NaN      NaN                        Friend or collegue
# 21        NaN      NaN                    Facebook group posting
# 22        NaN      NaN                    Facebook group posting
# 23        NaN      NaN                    Facebook group posting
# 24        NaN      NaN                        Friend or collegue
# 25        NaN      NaN                    Facebook group posting
# 26        NaN      NaN                        Friend or collegue
# 27        NaN      NaN                                       NaN
# 28        NaN      NaN                        Friend or collegue
# 29        NaN      NaN                        Friend or collegue
# ...       ...      ...                                       ...
# 2058      NaN      Yes                       Facebook Invitation
# 2059      NaN      Yes                       Facebook Invitation
# 2060      NaN      Yes                       Friend or Colleague
# 2061      NaN      Yes                       Facebook Invitation
# 2062      NaN      Yes                       Facebook Invitation
# 2063      NaN      NaN                                       NaN
# 2064      NaN      Yes                       Facebook Invitation
# 2065      NaN      Yes  Facebook Invitation, Friend or Colleague
# 2066      NaN      Yes                       Friend or Colleague
# 2067      NaN      Yes                       Friend or Colleague
# 2068      NaN       No                       Friend or Colleague
# 2069      NaN      Yes  Facebook Invitation, Friend or Colleague
# 2070      NaN      Yes                       Friend or Colleague
# 2071      NaN      Yes                       Friend or Colleague
# 2072      NaN      Yes                          Involvement Fair
# 2073      NaN       No         Facebook Invitation, DSI Listserv
# 2074      NaN      Yes                                     flyer
# 2075      NaN      Yes                              DSI Listserv
# 2076      NaN      Yes                              DSI Listserv
# 2077      NaN      Yes                       Friend or Colleague
# 2078      NaN      Yes                       Friend or Colleague
# 2079      NaN      Yes                              DSI Listserv
# 2080      NaN      Yes                       Facebook Invitation
# 2081      NaN      Yes                       Friend or Colleague
# 2082      NaN       No         Facebook Invitation, DSI Listserv
# 2083      NaN      Yes                       Friend or Colleague
# 2084      NaN      Yes                       Friend or Colleague
# 2085      NaN      Yes                       Friend or Colleague
# 2086      NaN      Yes                       Facebook Invitation
# 2087      NaN      Yes         Facebook Invitation, DSI Listserv
#
#      code background
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# ...              ...
# 2058             NaN
# 2059             NaN
# 2060             NaN
# 2061             NaN
# 2062             NaN
# 2063             NaN
# 2064             NaN
# 2065             NaN
# 2066             NaN
# 2067             NaN
# 2068             NaN
# 2069             NaN
# 2070             NaN
# 2071             NaN
# 2072             NaN
# 2073             NaN
# 2074             NaN
# 2075             NaN
# 2076             NaN
# 2077             NaN
# 2078             NaN
# 2079             NaN
# 2080             NaN
# 2081             NaN
# 2082             NaN
# 2083             NaN
# 2084             NaN
# 2085             NaN
# 2086             NaN
# 2087             NaN
#
# [2088 rows x 22 columns]

# %%
workshop_data['how did you hear about us'].value_counts(normalize=True).head(5).plot.barh()

# %%
workshop_data['email'].value_counts().hist()
