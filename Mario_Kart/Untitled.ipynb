# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
Mario_kart = pd.read_csv("KartKross.csv")

# %%
sns.scatterplot(data=Mario_kart, x='speed', y = 'acceleration')

# %%
Mario_kart
# Out:
#                  characters        kart         tires         glider  speed  \
# 0         Wario, Dry Bowser    Landship      Off-Road   Plane Glider   4.50
# 1         Wario, Dry Bowser    Landship      Off-Road    Bowser Kite   4.25
# 2         Wario, Dry Bowser    Landship      Off-Road     Wario Wing   4.50
# 3         Wario, Dry Bowser    Landship      Off-Road    Hylian Kite   4.50
# 4         Wario, Dry Bowser    Landship      Off-Road       Parafoil   4.25
# 5         Wario, Dry Bowser    Landship      Off-Road      Parachute   4.25
# 6         Wario, Dry Bowser    Landship      Off-Road   Cloud Glider   4.25
# 7         Wario, Dry Bowser    Landship      Off-Road  MKTV Parafoil   4.25
# 8         Wario, Dry Bowser    Landship      Off-Road    Gold Glider   4.50
# 9         Wario, Dry Bowser    Landship      Off-Road  Flower Glider   4.25
# 10        Wario, Dry Bowser    Landship      Off-Road   Super Glider   4.50
# ...

# %%
sns.distplot(Mario_kart['speed'])
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(Mario_kart['acceleration'])
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(Mario_kart['total'])
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
Mario_kart[Mario_kart['total'] == 23]
# Out:
#                              characters          kart         tires  \
# 35952  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35953  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35954  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35955  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35956  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35957  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35958  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35959  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35960  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35961  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35962  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35963  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# 35964  Koopa Troopa, Lakitu, Bowser Jr.    Pipe Frame        Roller
# ...

# %%
sns.scatterplot(data= Mario_kart, x= 'speed', y = 'weight')

# %%
df_gliders = pd.DataFrame(Mario_kart.groupby('glider').mean())

# %%
sns.barplot(data= df_gliders, x = df_gliders.index, y = 'traction')
