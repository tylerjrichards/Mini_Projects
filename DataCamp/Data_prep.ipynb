# %%
import sys

# %%
# !{sys.executable} -m pip install faker

# %%
import faker

# %%
from faker import Faker
fake = Faker()

fake.name()
# Out:
# 'John Fleming'

# %%
fake.name_male()

# %%
import pandas as pd

# %%
df_voters = pd.read_csv("DUV_20180911.txt",
                                header=None, sep="\t")
# Out:
# /usr/local/Cellar/ipython/6.5.0/libexec/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_header = pd.read_csv("header.csv", header=None)

# %%
df_header = df_header.apply(lambda s:s.str.replace('"', ""))

# %%
df_voters = df_header[0]

# %%
df_voters.columns = df_header.iloc[0]

# %%
df_voters
# Out:
# 0      County_Code   Voter_ID           Name_Last Name_Suffix    Name_First  \
# 0              DUV  114666408              Horton         NaN       Matthew
# 1              DUV  116936475              Fowler         NaN         Linda
# 2              DUV  114993867              Moores         NaN          Erin
# 3              DUV  120685979            Campbell         NaN         Brian
# 4              DUV  117026422     Blair Mcmullion         NaN          Cora
# 5              DUV  103878848              Graddy         NaN        Louise
# 6              DUV  103308019           Mc Carthy         III          John
# 7              DUV  103414861            Snelling         NaN       Deandre
# 8              DUV  118484655  Rodriguez De Jesus         NaN        Hector
# 9              DUV  118484639              Eggers         NaN         Maria
# 10             DUV  103608310             Hammond         NaN         Malie
# ...

# %%
df.apply(lambda s:s.str.replace('"', ""))
# Out:
#               0           1            2              3             4   \
# 0  "County_Code"  "Voter_ID"  "Name_Last"  "Name_Suffix"  "Name_First"
#
#               5                                     6   \
# 0  "Name_Middle"  "Requested_public_records_exemption"
#
#                            7                           8                 9   \
# 0  "Residence_Address_Line_1"  "Residence_Address_Line_2"  "Residence_City"
#
#         ...                     28                        29  \
# 0       ...         "Voter_Status"  "Congressional_District"
#
#                  30                 31                            32  \
# 0  "House_District"  "Senate_District"  "County_Commission_District"
#
#                         33                   34                      35  \
# 0  "School_Board_District"  "Daytime_Area_Code"  "Daytime_Phone_Number"
#
#                           36               37
# 0  "Daytime_Phone_Extension"  "Email_address"
#
# [1 rows x 38 columns]
